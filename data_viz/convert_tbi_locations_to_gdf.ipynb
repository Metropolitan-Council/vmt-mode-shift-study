# %% [markdown]
# Script to convert TBI location data to a geodataframe.

# %%
import numpy as np
import pandas as pd
import geopandas as gpd

import keyring

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# This is used to avoid hard-coding directories. 
# To set the directory, use the command prompt or a notebook you don't check in.  run:
# import keyring
# keyring.set_password("msp", "vmt_reduction_dir", <directory>)

# get base path for data
data_dir = keyring.get_password("msp", "vmt_reduction_dir")

# %%
df1 = pd.read_csv(data_dir + "/Data/TBI Wave 1 Dataset 20200630 - decoded/loc.csv", 
                 usecols = ['trip_id', 'lat', 'lon'])

# %%
df2 = pd.read_csv(data_dir + "/Data/Wave 2 Data Deliverable/location.csv", 
                 usecols = ['trip_id', 'lat', 'lon'])

# %%
df = df1.append(df2)

# %%
# read in the data
gdf1 = gpd.GeoDataFrame(df, geometry = gpd.points_from_xy(df.lon, df.lat))

# %%
gdf1.to_file(data_dir + "/Data_Processed/observed_locations.gpkg", 
             layer='location', driver="GPKG")

# %%
gdf1.to_parquet(data_dir + "/Data_processed/geodata/observed_locations.parquet", index=False)
