# %%
import pandas as pd
import geopandas as gp
import math
import keyring

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# User set the main directory using keyring.  For example:
#    import keyring
#    keyring.set_password('msp', 'vmt_reduction_dir', 'path to the desired directory')
# This will be saved on your local machine

data_dir = keyring.get_password('msp', 'vmt_reduction_dir')

# %%
df = pd.read_csv(data_dir + 'tbi_merged.csv')

# %%
df.head()

# %%
car_gf = gp.read_file(data_dir + 'car_trips.gpkg')

# %%
car_gf.head()

# %%
df_merged = car_gf.merge(df, on='trip_id', how='inner')

# %%
bike_gf = gp.read_file(data_dir + 'bike_trips.gpkg')

# %%
bike_gf.head()

# %%
df_merged = df_merged.merge(bike_gf, on='trip_id', how='left', suffixes=['_car', '_bike'])

# %%
df_merged.head()

# %%
import folium

# %%
m = folium.Map(location=[44.9778,-93.2650])

# %%
m

# %%
line = df_merged.loc[0].geometry_car

# %%
feature = folium.GeoJson(line)

# %%
feature

# %%
feature.add_to(m)

# %%
m

# %%
feature = folium.GeoJson(df_merged.loc[0].geometry_bike)
feature.add_to(m)

# %%
m

# %% [markdown]
# ## Notes to Rich on desired features
#
# - Add route for car, bike, walk (do transit last due to the difference in merging)
# - Color code each one differently
# - Add hover tool or pop up box for car, bike and walk routes showing:
#     - Add any attributes that show up in the gpkg files in a hover tool.  This is spartan for now, but will expand.
# - Set map zoom in some sensible way so it starts as a box around the routes
# - Show a couple of examples of queries

# %%
# query option 1: Select a random row
row = df_merged.sample(n=1)
row

# %%
# query option 2: Select rows that meet some criteria
df_query = df_merged[df_merged['distance_meters_bike'].isnull()]
df_query

# %%
# query option 2: Select rows that meet some criteria
df_query = df_merged[(df_merged['distance_meters_bike']<1000) & (df_merged['mode']=='Bike/Scooter')]
df_query

# %%
df_merged['mode'].unique()
